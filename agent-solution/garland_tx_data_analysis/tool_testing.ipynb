# %% [markdown]
# # Tool Testing Notebook
# This notebook is for testing the tools in the `garland_tx_data_analysis` project.

# %% [markdown]
# ### 1. Import Required Libraries

# %%
import sys
import os
import importlib

# Add the src directory to Python path
sys.path.insert(0, os.path.join(os.getcwd(), 'src'))

# Import the module
from garland_tx_data_analysis.tools import custom_tool

# Reload the module to pick up recent changes
importlib.reload(custom_tool)

# Import the class after reloading
from garland_tx_data_analysis.tools.custom_tool import PDFIncidentExtractorTool

# %% [markdown]
# ### 2. Define the Tool for Testing

# %%
pdf_extraction_tool = PDFIncidentExtractorTool()

# %% [markdown]
# ### 3. Prepare Sample Data

# %%
# The PDF file downloaded in the previous step will be used.
pdf_path = "police_incidents_weekly.pdf"

# %% [markdown]
# ### 4. Execute the Test

# %%
extracted_incidents = pdf_extraction_tool._run(pdf_path=pdf_path)
print("Extracted Incidents:")
for incident in extracted_incidents:
    print(incident)
# Out:
# District 21: 2 incidents
# District 22: 7 incidents
# District 23: 2 incidents
# District 24: 6 incidents
# District 25: 4 incidents
# District 26: 6 incidents
# District 31: 6 incidents
# District 32: 9 incidents
# District 33: 1 incidents
# District 34: 3 incidents
# District 35: 4 incidents
# District 36: 0 incidents
# District 37: 4 incidents
# District 41: 5 incidents
# District 42: 2 incidents
# District 43: 4 incidents
# District 44: 1 incidents
# District 45: 3 incidents
# District 46: 3 incidents
# District 51: 6 incidents
# District 52: 10 incidents
# District 53: 10 incidents
# District 54: 7 incidents
# District 55: 4 incidents
# District 56: 4 incidents
# Extracted Incidents:
# {'date': '12/10/2025', 'incident': 'BURGLARY-VEH', 'location': '34XX CROSSBOW LN', 'district': '21'}
# {'date': '12/13/2025', 'incident': 'UNAUTHORIZED USE MOTOR VEHICLE', 'location': '28XX ST GEORGE DR', 'district': '21'}
# {'date': '12/09/2025', 'incident': 'THEFT-MAIL <10 ADDRESSES', 'location': '60XX NAAMAN FOREST BLVD', 'district': '22'}
# {'date': '12/10/2025', 'incident': 'THEFT-MAIL <10 ADDRESSES', 'location': '62XX NAAMAN FOREST BLVD', 'district': '22'}
# {'date': '12/10/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': 'ARROWCREST LN', 'district': '22'}
# {'date': '12/10/2025', 'incident': 'CRIMINAL MISCHIEF $750 L/T $2,500', 'location': 'ARROWCREST LN', 'district': '22'}
# {'date': '12/11/2025', 'incident': 'THEFT BY CHECK-$30,000 L/T $150,000', 'location': '24XX ARAPAHO RD', 'district': '22'}
# {'date': '12/11/2025', 'incident': 'THEFT-MAIL <10 ADDRESSES', 'location': '62XX NAAMAN FOREST BLVD', 'district': '22'}
# {'date': '12/12/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '63XX NAAMAN FOREST BLVD', 'district': '22'}
# {'date': '12/08/2025', 'incident': 'THEFT-ALL OTHER-$30,000 L/T $150,000', 'location': '34XX WAGON WHEEL RD', 'district': '23'}
# {'date': '12/10/2025', 'incident': 'BURGLARY-VEH', 'location': '14XX BELT LINE RD', 'district': '23'}
# {'date': '12/07/2025', 'incident': 'BURGLARY-HAB', 'location': '42XX WINDSOR DR', 'district': '24'}
# {'date': '12/09/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '40XX GLENROSE DR', 'district': '24'}
# {'date': '12/09/2025', 'incident': 'THEFT-ALL OTHER-L/T $100', 'location': '35XX W WALNUT ST', 'district': '24'}
# {'date': '12/10/2025', 'incident': 'BURGLARY-BLDG', 'location': '2XX N FOREST CREST DR', 'district': '24'}
# {'date': '12/13/2025', 'incident': 'BURGLARY-VEH', 'location': '40XX FOREST LN', 'district': '24'}
# {'date': '12/13/2025', 'incident': 'THEFT-MOTOR VEH PARTS/ACCESSORIES-$2,500 L/T $30,000', 'location': '40XX FOREST LN', 'district': '24'}
# {'date': '12/09/2025', 'incident': 'INFO-THEFT', 'location': '13XX N SHILOH RD', 'district': '25'}
# {'date': '12/10/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '19XX N JUPITER RD', 'district': '25'}
# {'date': '12/12/2025', 'incident': 'INFO-THEFT', 'location': '21XX W WALNUT ST', 'district': '25'}
# {'date': '12/13/2025', 'incident': 'BURGLARY-BLDG', 'location': '33XX W WALNUT ST', 'district': '25'}
# {'date': '12/07/2025', 'incident': 'THEFT-SHOPLIFTING-$100 L/T $750', 'location': '14XX W WALNUT ST', 'district': '26'}
# {'date': '12/08/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '29XX EDGEWOOD DR', 'district': '26'}
# {'date': '12/09/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '34XX W WALNUT ST', 'district': '26'}
# {'date': '12/11/2025', 'incident': 'THEFT-ALL OTHER-$750 L/T $2,500', 'location': '14XX W WALNUT ST', 'district': '26'}
# {'date': '12/12/2025', 'incident': 'UNAUTHORIZED USE MOTOR VEHICLE-(CRIM ATT)', 'location': '30XX EDGEWOOD DR', 'district': '26'}
# {'date': '12/13/2025', 'incident': 'UNAUTHORIZED USE MOTOR VEHICLE', 'location': '32XX FOREST LN', 'district': '26'}
# {'date': '12/09/2025', 'incident': 'THEFT OF SERVICE-L/T $100', 'location': '50XX N GEORGE BUSH RAMP', 'district': '31'}
# {'date': '12/10/2025', 'incident': 'BURGLARY-VEH', 'location': '48XX NAAMAN FOREST BLVD', 'district': '31'}
# {'date': '12/10/2025', 'incident': 'THEFT-MOTOR VEH PARTS/ACCESSORIES-$750 L/T $2,500', 'location': '46XX SATURN RD', 'district': '31'}
# {'date': '12/11/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '7XX W BUCKINGHAM RD', 'district': '31'}
# {'date': '12/12/2025', 'incident': 'CRIMINAL MISCHIEF L/T $100', 'location': '4XX WILLOWCREST DR', 'district': '31'}
# {'date': '12/13/2025', 'incident': 'BURGLARY-BLDG', 'location': '34XX NAAMAN SCHOOL RD', 'district': '31'}
# {'date': '12/07/2025', 'incident': 'THEFT PROP < $2,500 2 / MORE PREV CONV', 'location': '31XX N GEORGE BUSH HWY', 'district': '32'}
# {'date': '12/07/2025', 'incident': 'THEFT PROP < $2,500 2 / MORE PREV CONV', 'location': '31XX N GEORGE BUSH HWY', 'district': '32'}
# {'date': '12/07/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '29XX LAVON DR', 'district': '32'}
# {'date': '12/07/2025', 'incident': 'THEFT-ALL OTHER-L/T $100', 'location': '4XX TOWN CENTER BLVD', 'district': '32'}
# {'date': '12/08/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '41XX BUNKER HILL RD', 'district': '32'}
# {'date': '12/08/2025', 'incident': 'THEFT-SHOPLIFTING-$100 L/T $750', 'location': '2XX CONEFLOWER DR', 'district': '32'}
# {'date': '12/11/2025', 'incident': 'THEFT-MOTOR VEHICLE-$2,500 L/T $30,000', 'location': '32XX N GEORGE BUSH RAMP', 'district': '32'}
# {'date': '12/11/2025', 'incident': 'INFO-IDENTITY THEFT', 'location': '15XX PLEASANT VALLEY RD', 'district': '32'}
# {'date': '12/11/2025', 'incident': 'THEFT-SHOPLIFTING-$100 L/T $750', 'location': '1XX CEDAR SAGE DR', 'district': '32'}
# {'date': '12/13/2025', 'incident': 'THEFT-SHOPLIFTING-L/T $100', 'location': '11XX N COUNTRY CLUB RD', 'district': '33'}
# {'date': '12/07/2025', 'incident': 'BURGLARY-VEH', 'location': '2XX N FIFTH ST', 'district': '34'}
# {'date': '12/10/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '12XX TRAVIS ST', 'district': '34'}
# {'date': '12/13/2025', 'incident': 'BURGLARY-VEH', 'location': '3XX N FIFTH ST', 'district': '34'}
# {'date': '12/08/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '8XX E WALNUT ST', 'district': '35'}
# {'date': '12/08/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '8XX E WALNUT ST', 'district': '35'}
# {'date': '12/09/2025', 'incident': 'THEFT-VEHICLE (NON-MOTOR VEH)-$2,500 L/T $30,000', 'location': '28XX CENTERVILLE RD', 'district': '35'}
# {'date': '12/10/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '8XX E WALNUT ST', 'district': '35'}
# {'date': '12/09/2025', 'incident': 'CRIMINAL MISCHIEF $750 L/T $2,500', 'location': '15XX CUMBERLAND DR', 'district': '37'}
# {'date': '12/10/2025', 'incident': 'INFO-VEH THEFT', 'location': '10XX CURTIS DR', 'district': '37'}
# {'date': '12/10/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '2XX SOUTHWOOD DR', 'district': '37'}
# {'date': '12/10/2025', 'incident': 'CRIMINAL MISCHIEF $750 L/T $2,500', 'location': '2XX SOUTHWOOD DR', 'district': '37'}
# {'date': '12/07/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '28XX BEASLEY DR', 'district': '41'}
# {'date': '12/08/2025', 'incident': 'THEFT-ALL OTHER-$30,000 L/T $150,000', 'location': '28XX S SHILOH RD', 'district': '41'}
# {'date': '12/10/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '22XX EXECUTIVE DR', 'district': '41'}
# {'date': '12/10/2025', 'incident': 'BURGLARY-VEH', 'location': '13XX ELMHURST DR', 'district': '41'}
# {'date': '12/11/2025', 'incident': 'THEFT-ALL OTHER-$2,500 L/T $30,000', 'location': '24XX MERRITT DR', 'district': '41'}
# {'date': '12/09/2025', 'incident': 'ASSAULT-AGG-D/W', 'location': '21XX SKILLMAN DR', 'district': '42'}
# {'date': '12/13/2025', 'incident': 'THEFT-ALL OTHER-L/T $100', 'location': '6XX E LINDA DR', 'district': '42'}
# {'date': '12/08/2025', 'incident': 'THEFT-VEHICLE (NON-MOTOR VEH)-$2,500 L/T $30,000', 'location': '122XX LBJ FRWY', 'district': '43'}
# {'date': '12/09/2025', 'incident': 'THEFT-MOTOR VEH PARTS/ACCESSORIES-$2,500 L/T $30,000', 'location': '28XX W KINGSLEY RD', 'district': '43'}
# {'date': '12/09/2025', 'incident': 'THEFT-VEHICLE (NON-MOTOR VEH)-$2,500 L/T $30,000', 'location': '39XX ROANOKE DR', 'district': '43'}
# {'date': '12/11/2025', 'incident': 'BURGLARY-VEH', 'location': '19XX WALL ST', 'district': '43'}
# {'date': '12/11/2025', 'incident': 'THEFT-ALL OTHER-$2,500 L/T $30,000', 'location': '33XX OLD ORCHARD RD', 'district': '44'}
# {'date': '12/09/2025', 'incident': 'UNAUTHORIZED USE MOTOR VEHICLE', 'location': '39XX LEEDS CT', 'district': '45'}
# {'date': '12/11/2025', 'incident': 'BURGLARY-VEH', 'location': '31XX BROADWAY BLVD', 'district': '45'}
# {'date': '12/12/2025', 'incident': 'THEFT-ALL OTHER-$750 L/T $2,500', 'location': '32XX OAK HILL DR', 'district': '45'}
# {'date': '12/10/2025', 'incident': 'THEFT-SHOPLIFTING-$100 L/T $750', 'location': '18XX MARKETPLACE DR', 'district': '46'}
# {'date': '12/10/2025', 'incident': 'THEFT-ALL OTHER-$100 L/T $750', 'location': '8XX W CENTERVILLE RD', 'district': '46'}
# {'date': '12/11/2025', 'incident': 'THEFT-ALL OTHER-$30,000 L/T $150,000', 'location': '8XX W CENTERVILLE RD', 'district': '46'}
# {'date': '12/07/2025', 'incident': 'THEFT-SHOPLIFTING-$100 L/T $750', 'location': '11XX W CENTERVILLE RD', 'district': '51'}
# {'date': '12/08/2025', 'incident': 'THEFT-MAIL <10 ADDRESSES', 'location': '50XX PRESIDIO DR', 'district': '51'}
# {'date': '12/09/2025', 'incident': 'BURGLARY-BLDG-(CRIM ATT)', 'location': '13XX W CENTERVILLE RD', 'district': '51'}
# {'date': '12/09/2025', 'incident': 'CRIMINAL MISCHIEF $750 L/T $2,500', 'location': '13XX W CENTERVILLE RD', 'district': '51'}
# {'date': '12/10/2025', 'incident': 'CRIMINAL MISCHIEF $2,500 L/T $30,000', 'location': '', 'district': '51'}
# {'date': '12/11/2025', 'incident': 'THEFT BY CHECK-$30,000 L/T $150,000', 'location': '3XX W CENTERVILLE RD', 'district': '51'}
# {'date': '12/07/2025', 'incident': 'THEFT PROP < $2,500 2 / MORE PREV CONV', 'location': '5XX W I30 FRWY', 'district': '52'}
# {'date': '12/08/2025', 'incident': 'THEFT-SHOPLIFTING-L/T $100', 'location': '5XX W I30 FRWY', 'district': '52'}
# {'date': '12/09/2025', 'incident': 'THEFT-SHOPLIFTING-$100 L/T $750', 'location': '5XX W I30 FRWY', 'district': '52'}
# {'date': '12/11/2025', 'incident': 'UNAUTHORIZED USE MOTOR VEHICLE', 'location': '7XX CHAMPION CT', 'district': '52'}
# {'date': '12/11/2025', 'incident': 'ASSAULT-AGG-D/W', 'location': '63XX BROADWAY BLVD', 'district': '52'}
# {'date': '12/12/2025', 'incident': 'BURGLARY-VEH', 'location': '61XX HILLSIDE LN', 'district': '52'}
# {'date': '12/12/2025', 'incident': 'BURGLARY-VEH', 'location': '61XX HILLSIDE LN', 'district': '52'}
# {'date': '12/12/2025', 'incident': 'BURGLARY-VEH', 'location': '61XX CYPRESS POINT DR', 'district': '52'}
# {'date': '12/12/2025', 'incident': 'BURGLARY-VEH', 'location': '7XX PEBBLE BEACH DR', 'district': '52'}
# {'date': '12/12/2025', 'incident': 'UNAUTHORIZED USE MOTOR VEHICLE', 'location': '3XX ALLEGHENY TRAIL LN', 'district': '52'}
# {'date': '12/07/2025', 'incident': 'ASSAULT-AGG-D/W', 'location': '42XX ROSEHILL RD', 'district': '53'}
# {'date': '12/08/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '52XX BROADWAY BLVD', 'district': '53'}
# {'date': '12/08/2025', 'incident': 'THEFT-MAIL <10 ADDRESSES', 'location': '53XX MEADOWSIDE DR', 'district': '53'}
# {'date': '12/08/2025', 'incident': 'INJURY TO A DISABLED INDIV-BI', 'location': '48XX GATEWOOD RD', 'district': '53'}
# {'date': '12/09/2025', 'incident': 'BURGLARY-VEH', 'location': '61XX DUCK CREEK DR', 'district': '53'}
# {'date': '12/09/2025', 'incident': 'BURGLARY-VEH', 'location': '61XX DUCK CREEK DR', 'district': '53'}
# {'date': '12/09/2025', 'incident': 'BURGLARY-VEH', 'location': '63XX DUCK CREEK DR', 'district': '53'}
# {'date': '12/09/2025', 'incident': 'BURGLARY-VEH', 'location': '5XX TACOMA DR', 'district': '53'}
# {'date': '12/11/2025', 'incident': 'UNAUTHORIZED USE MOTOR VEHICLE', 'location': '54XX ROBIN RD', 'district': '53'}
# {'date': '12/11/2025', 'incident': 'BURGLARY-VEH', 'location': '12XX SUNSCAPE WY', 'district': '53'}
# {'date': '12/08/2025', 'incident': 'THEFT-ALL OTHER-L/T $100', 'location': '43XX KETTERING DR', 'district': '54'}
# {'date': '12/10/2025', 'incident': 'BURGLARY-VEH', 'location': '44XX SCENIC CIR', 'district': '54'}
# {'date': '12/10/2025', 'incident': 'BURGLARY-VEH', 'location': '46XX CANDLESTICK DR', 'district': '54'}
# {'date': '12/10/2025', 'incident': 'BURGLARY-VEH', 'location': '45XX SCENIC CIR', 'district': '54'}
# {'date': '12/11/2025', 'incident': 'UNAUTHORIZED USE MOTOR VEHICLE', 'location': '', 'district': '54'}
# {'date': '12/12/2025', 'incident': 'BURGLARY-VEH', 'location': '34XX BOBTOWN RD', 'district': '54'}
# {'date': '12/13/2025', 'incident': 'BURGLARY-VEH', 'location': '45XX I30 FRWY', 'district': '54'}
# {'date': '12/09/2025', 'incident': 'THEFT-MOTOR VEH PARTS/ACCESSORIES-L/T $100', 'location': '3XX W I30 FRWY', 'district': '55'}
# {'date': '12/12/2025', 'incident': 'THEFT-SHOPLIFTING-$100 L/T $750', 'location': '62XX BROADWAY BLVD', 'district': '55'}
# {'date': '12/13/2025', 'incident': 'INFO-IDENTITY THEFT', 'location': '28XX GUTHRIE RD', 'district': '55'}
# {'date': '12/13/2025', 'incident': 'THEFT-SHOPLIFTING-$750 L/T $2,500', 'location': '62XX BROADWAY BLVD', 'district': '55'}
# {'date': '12/07/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '137XX I30 FRWY', 'district': '56'}
# {'date': '12/09/2025', 'incident': 'CRIMINAL MISCHIEF $100 L/T $750', 'location': '60XX BAY ISLAND DR', 'district': '56'}
# {'date': '12/10/2025', 'incident': 'ROBBERY-INDIV', 'location': '44XX BASS PRO DR', 'district': '56'}
# {'date': '12/12/2025', 'incident': 'INFO-IDENTITY THEFT', 'location': '45XX CHAHA RD', 'district': '56'}

# %% [markdown]
# ### 5. Analyze the Results

# %%
import json
print(json.dumps(extracted_incidents, indent=2))
# Add an assertion to check if incidents were extracted
assert isinstance(extracted_incidents, list)
print(f"Extracted {len(extracted_incidents)} lines from the PDF.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import json
# ----> 2 print(json.dumps(extracted_incidents, indent=2))
#       3 # Add an assertion to check if incidents were extracted
#       4 assert isinstance(extracted_incidents, list)
#
# NameError: name 'extracted_incidents' is not defined

# %%
### 6. Test IncidentFormattingTool

# %%
# Test the IncidentFormattingTool
from garland_tx_data_analysis.tools.custom_tool import IncidentFormattingTool

formatting_tool = IncidentFormattingTool()

# Format the extracted incidents
result = formatting_tool._run(incidents=extracted_incidents, output_path="test_formatted_incidents.json")
print(result)
